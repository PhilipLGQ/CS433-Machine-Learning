# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import files to use in preprocessing and machine learning
from implementations import *
from proj1_helpers import *
from preprocess import *
from cross_validation import *

# %% [markdown]
# ## Load the training data into feature matrix, class labels, and event ids:

# %%
# Download train data and supply path here 
DATA_TRAIN_PATH = '../data/train.csv' 
y, tX, ids = load_csv_data(DATA_TRAIN_PATH)

# %% [markdown]
# # Initial Data Analysis

# %% [markdown]
# In observing the original training data, we found out that there exists missing data all over tX. The missing data are represented as value -999. Considering that these columns are critical in model training, we cannot simply delete these rows with -999 values. Therefore, we need to process the original training set before model training.

# %% [markdown]
# Firstly, we check the columns of tX to obtain an overview of missing data:

# %% [markdown]
# We can see that 11 columns contains at least one -999 (missing value). Now we check whether some of the missing values are dependent on the column named 'PRI_jet_num' (column No. 23), since 'PRI_jet_num' has a discrete value range {0, 1, 2, 3} and our observation on the beginning data rows showed a dependency of some missing values to the value of 'PRI_jet_num' column.

# %% [markdown]
# The above analysis showed that one column with -999 (missing value) is independent of the column 'PRI_jet_num', we check the original training set and we can easily find out that the first tX column 'DER_mass_MMC' is independent of 'PRI_jet_num'.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Based on the data analysis above, we conduct the following method to pre-process the training data.

# %%
# Split the database based on 'PRI_jet_num' (0, 1, 2&3)
tX_jet_0, tX_jet_1, tX_jet_23, y_jet_0, y_jet_1, y_jet_23, r_ids = split_reformat_data(tX, y, ids)

print(tX_jet_0.shape)
print(tX_jet_1.shape)
print(tX_jet_23.shape)
# Out:
# (99913, 18)
# (77544, 22)
# (72543, 29)

# %%
def k_means_cluster(data, y, k, max_iter=20):
    data = np.asarray(data, np.float32)
    indices = np.random.randint(0,data.shape[0],(1,k)).tolist()
    #print(indices)
    center = np.copy(data[indices])
    cluster = np.zeros(data.shape[0])
    for i in range(0,max_iter):
        one_hot1 = np.zeros(k*data.shape[0], np.float32)
        distance = np.sqrt(np.sum(np.square(np.expand_dims(data, axis=1) - center), axis=2))
        cluster = np.argmin(distance, axis=1)
        one_hot1[np.argmin(distance, axis=1) + np.arange(data.shape[0]) * k] = 1.
        one_hot2 = np.reshape(one_hot1, (data.shape[0], k))
        center = np.matmul(np.transpose(one_hot2, (1, 0)), data) / np.expand_dims(np.sum(one_hot2, axis=0), axis=1)     
    class_y = np.zeros((2, np.asarray(np.argmin(distance, axis=1)).shape[0]))
    class_y[0] = np.asarray(cluster)
    class_y[1] = np.asarray(y[0].T)[:,0]
    y_center = []
    for i in range(k):
        y_center.append(np.mean(class_y[1][class_y[0,:]==i]))
    return cluster, center, np.array(y_center)

def k_means_replacing(xx, k=11):
    normal_x = np.mat(np.delete(xx[xx[:, 0] != -999], np.r_[0], axis=1)) 
    abnormal_x = np.mat(np.delete(xx[xx[:, 0] == -999], np.r_[0], axis=1))
    normal_y = np.mat(xx[xx[:, 0]!= -999][:,0])
    cluster, center, y_center = k_means_cluster(normal_x,normal_y, k)
    replace_list = np.zeros((abnormal_x.shape[0],1))
    for j in range(abnormal_x.shape[0]):
        #if j%100 == 0:
            #print('Replacing '+str(j)+' out of'+str(abnormal_x.shape[0]))       
        tt = np.zeros((center.shape[0],center.shape[1]))
        for i in range(center.shape[0]):
            tt[i] = abnormal_x[j]
        ff = np.mat(tt-center)
        distance_matrix = np.array((ff*ff.T).diagonal()).T
        class_num = np.argmin(distance_matrix)
        replace_list[j] = y_center[class_num]
    replace_list = np.c_[replace_list,abnormal_x]
    xx[np.where(xx[:, 0]== -999)[0]] = replace_list

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Ridge Regression

# %%
def find_optimal(x, y, degrees, k_fold, lambdas, k_clusters, seed=1):
    # Split the data into k-fold
    k_indices = build_k_indices(y, k_fold, seed)
    x_k = x.copy()
    # Set lists for collecting best lambda & rmse for each degree
    best_lambda = []
    best_rmse = []
    best_k = []
    best_degree = []
    
    for k_mean in k_clusters:
        x_k = x.copy()
        k_cluster = 10*k_mean+5
        k_means_replacing(x_k, k_cluster)
        x_k = normalize(standardize(x_k))
        for degree in degrees:
            rmse_val = []
        
            for lambda_ in lambdas:
                rmse_val_lambda_ = []
            
                for k in range(k_fold):
                    _, loss_val, w = cross_validation(y, x_k, k_indices, k, lambda_, degree)
                    rmse_val_lambda_.append(loss_val)
                
                print("No. of clusters {}".format(k_cluster))
                print("lambda {}".format(lambda_))
                
                print("loss {}".format(np.mean(rmse_val_lambda_)))
                print("degree {}".format(degree))
                print("\n\n")

                rmse_val.append(np.mean(rmse_val_lambda_))
        
            index_opt_lambda = np.argmin(rmse_val)
            best_lambda.append(lambdas[index_opt_lambda])
            best_rmse.append(rmse_val[index_opt_lambda])
            best_k.append(k_mean)
            best_degree.append(degree)

    opt_degree = best_degree[np.argmin(best_rmse)]
    opt_lambda = best_lambda[np.argmin(best_rmse)]
    opt_k = best_k[np.argmin(best_rmse)]
    
    return opt_degree, opt_lambda, opt_k

# %%
ls_opt_d = []
ls_opt_l = []
ls_opt_K = []

t0, t1, t2 = tX_jet_0.copy(), tX_jet_1.copy(), tX_jet_23.copy()
y0, y1, y2 = y_jet_0.copy(), y_jet_1.copy(), y_jet_23.copy()

train_set = [[t0, y0],[t1, y1],[t2, y2]]
# Set H-parameters
K_FOLD = 10
DEGREE = np.arange(4, 9)
k_clusters= np.arange(1,11)
SEED = 5
LAMBDA = np.logspace(-8, -3, 40)

for tx, y in train_set:
    opt_d, opt_l, opt_k= find_optimal(tx, y, DEGREE, K_FOLD, LAMBDA, k_clusters)
    print(opt_d, opt_l, opt_k)
    ls_opt_d.append(opt_d)
    ls_opt_l.append(opt_l)
    ls_opt_K.append(opt_k)
# Out:
# No. of clusters 15
# lambda 1e-08
# loss 0.7902881266033355
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.3433993325988987e-08
# loss 0.7901464701702299
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.8047217668271702e-08
# loss 0.7900094605427315
# degree 4
#
#
#
# No. of clusters 15
# lambda 2.424462017082331e-08
# loss 0.7898871586624165
# degree 4
#
#
#
# No. of clusters 15
# lambda 3.257020655659783e-08
# loss 0.7897896000357715
# degree 4
#
#
#
# No. of clusters 15
# lambda 4.37547937507418e-08
# loss 0.789725351517262
# degree 4
#
#
#
# No. of clusters 15
# lambda 5.878016072274912e-08
# loss 0.789700603466853
# degree 4
#
#
#
# No. of clusters 15
# lambda 7.896522868499733e-08
# loss 0.7897193295602778
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.0608183551394483e-07
# loss 0.7897845712718852
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.4251026703029963e-07
# loss 0.7899003925467503
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.9144819761699575e-07
# loss 0.7900738914664809
# degree 4
#
#
#
# No. of clusters 15
# lambda 2.571913809059347e-07
# loss 0.7903167865351367
# degree 4
#
#
#
# No. of clusters 15
# lambda 3.4551072945922185e-07
# loss 0.7906461303281387
# degree 4
#
#
#
# No. of clusters 15
# lambda 4.6415888336127725e-07
# loss 0.7910835285457221
# degree 4
#
#
#
# No. of clusters 15
# lambda 6.235507341273912e-07
# loss 0.791652250966646
# degree 4
#
#
#
# No. of clusters 15
# lambda 8.376776400682924e-07
# loss 0.7923722858198835
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.1253355826007646e-06
# loss 0.7932545923135883
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.51177507061566e-06
# loss 0.7942966292112532
# degree 4
#
#
#
# No. of clusters 15
# lambda 2.030917620904735e-06
# loss 0.7954807709136754
# degree 4
#
#
#
# No. of clusters 15
# lambda 2.7283333764867697e-06
# loss 0.7967757919233367
# degree 4
#
#
#
# No. of clusters 15
# lambda 3.665241237079626e-06
# loss 0.7981406123230357
# degree 4
#
#
#
# No. of clusters 15
# lambda 4.923882631706732e-06
# loss 0.799529625528235
# degree 4
#
#
#
# No. of clusters 15
# lambda 6.6147406412301455e-06
# loss 0.8008992463950525
# degree 4
#
#
#
# No. of clusters 15
# lambda 8.886238162743407e-06
# loss 0.8022148396260882
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.1937766417144358e-05
# loss 0.8034563812943609
# degree 4
#
#
#
# No. of clusters 15
# lambda 1.6037187437513277e-05
# loss 0.804621193259196
# degree 4
#
#
#
# No. of clusters 15
# lambda 2.1544346900318823e-05
# loss 0.8057230943541628
# degree 4
#
#
#
# No. of clusters 15
# lambda 2.8942661247167517e-05
# loss 0.8067885586718566
# degree 4
#
#
#
# No. of clusters 15
# lambda 3.888155180308085e-05
# loss 0.8078512021922768
# degree 4
#
#
#
# No. of clusters 15
# lambda 5.223345074266833e-05
# loss 0.8089460402039315
# degree 4
#
#
#
# No. of clusters 15
# lambda 7.017038286703822e-05
# loss 0.8101048400353508
# degree 4
#
#
#
# No. of clusters 15
# lambda 9.426684551178853e-05
# loss 0.8113537355167366
# degree 4
#
#
#
# No. of clusters 15
# lambda 0.00012663801734674022
# loss 0.8127137109389668
# degree 4
#
#
#
# No. of clusters 15
# lambda 0.00017012542798525856
# loss 0.8142032139581646
# degree 4
#
#
#
# No. of clusters 15
# lambda 0.00022854638641349884
# loss 0.815840673621692
# degree 4
#
#
#
# No. of clusters 15
# lambda 0.00030702906297578496
# loss 0.8176446961578667
# degree 4
#
#
#
# No. of clusters 15
# lambda 0.00041246263829013477
# loss 0.8196319085848718
# degree 4
#
#
#
# No. of clusters 15
# lambda 0.000554102033000948
# loss 0.8218151865445252
# degree 4
#
#
#
# No. of clusters 15
# lambda 0.000744380301325168
# loss 0.8242055562234087
# degree 4
#
#
#
# No. of clusters 15
# lambda 0.001
# loss 0.8268183541834068
# degree 4
#
#
#
# No. of clusters 15
# lambda 1e-08
# loss 0.7789722628947267
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.3433993325988987e-08
# loss 0.7792507505066568
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.8047217668271702e-08
# loss 0.7796107900515976
# degree 5
#
#
#
# No. of clusters 15
# lambda 2.424462017082331e-08
# loss 0.7800505577054315
# degree 5
#
#
#
# No. of clusters 15
# lambda 3.257020655659783e-08
# loss 0.7805632816552542
# degree 5
#
#
#
# No. of clusters 15
# lambda 4.37547937507418e-08
# loss 0.7811345279038362
# degree 5
#
#
#
# No. of clusters 15
# lambda 5.878016072274912e-08
# loss 0.781742076561337
# degree 5
#
#
#
# No. of clusters 15
# lambda 7.896522868499733e-08
# loss 0.782359101859014
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.0608183551394483e-07
# loss 0.7829595287520688
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.4251026703029963e-07
# loss 0.7835232333531427
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.9144819761699575e-07
# loss 0.7840391533895568
# degree 5
#
#
#
# No. of clusters 15
# lambda 2.571913809059347e-07
# loss 0.7845058669095066
# degree 5
#
#
#
# No. of clusters 15
# lambda 3.4551072945922185e-07
# loss 0.7849304919180311
# degree 5
#
#
#
# No. of clusters 15
# lambda 4.6415888336127725e-07
# loss 0.7853271034177689
# degree 5
#
#
#
# No. of clusters 15
# lambda 6.235507341273912e-07
# loss 0.7857154427848558
# degree 5
#
#
#
# No. of clusters 15
# lambda 8.376776400682924e-07
# loss 0.7861200626911048
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.1253355826007646e-06
# loss 0.7865695246448714
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.51177507061566e-06
# loss 0.7870949008807776
# degree 5
#
#
#
# No. of clusters 15
# lambda 2.030917620904735e-06
# loss 0.7877267750160406
# degree 5
#
#
#
# No. of clusters 15
# lambda 2.7283333764867697e-06
# loss 0.7884904991199673
# degree 5
#
#
#
# No. of clusters 15
# lambda 3.665241237079626e-06
# loss 0.7894006509887683
# degree 5
#
#
#
# No. of clusters 15
# lambda 4.923882631706732e-06
# loss 0.790456683656231
# degree 5
#
#
#
# No. of clusters 15
# lambda 6.6147406412301455e-06
# loss 0.7916416377874064
# degree 5
#
#
#
# No. of clusters 15
# lambda 8.886238162743407e-06
# loss 0.7929244632867232
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.1937766417144358e-05
# loss 0.7942652037040773
# degree 5
#
#
#
# No. of clusters 15
# lambda 1.6037187437513277e-05
# loss 0.7956219686840055
# degree 5
#
#
#
# No. of clusters 15
# lambda 2.1544346900318823e-05
# loss 0.7969587045872832
# degree 5
#
#
#
# No. of clusters 15
# lambda 2.8942661247167517e-05
# loss 0.7982523900063028
# degree 5
#
#
#
# No. of clusters 15
# lambda 3.888155180308085e-05
# loss 0.7994977536934013
# degree 5
#
#
#
# No. of clusters 15
# lambda 5.223345074266833e-05
# loss 0.8007079074808185
# degree 5
#
#
#
# No. of clusters 15
# lambda 7.017038286703822e-05
# loss 0.8019105728347723
# degree 5
#
#
#
# No. of clusters 15
# lambda 9.426684551178853e-05
# loss 0.8031411324761256
# degree 5
#
#
#
# No. of clusters 15
# lambda 0.00012663801734674022
# loss 0.8044348654662018
# degree 5
#
#
#
# No. of clusters 15
# lambda 0.00017012542798525856
# loss 0.8058211174997861
# degree 5
#
#
#
# No. of clusters 15
# lambda 0.00022854638641349884
# loss 0.8073215388290216
# degree 5
#
#
#
# No. of clusters 15
# lambda 0.00030702906297578496
# loss 0.8089526778690814
# degree 5
#
#
#
# No. of clusters 15
# lambda 0.00041246263829013477
# loss 0.8107307908051888
# degree 5
#
#
#
# No. of clusters 15
# lambda 0.000554102033000948
# loss 0.8126754403088035
# degree 5
#
#
#
# No. of clusters 15
# lambda 0.000744380301325168
# loss 0.8148096922093622
# degree 5
#
#
#
# No. of clusters 15
# lambda 0.001
# loss 0.8171577636137697
# degree 5
#
#
#
# No. of clusters 15
# lambda 1e-08
# loss 0.7767422854480127
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.3433993325988987e-08
# loss 0.7767673439698358
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.8047217668271702e-08
# loss 0.7768422703925678
# degree 6
#
#
#
# No. of clusters 15
# lambda 2.424462017082331e-08
# loss 0.7769673853233068
# degree 6
#
#
#
# No. of clusters 15
# lambda 3.257020655659783e-08
# loss 0.7771441120481192
# degree 6
#
#
#
# No. of clusters 15
# lambda 4.37547937507418e-08
# loss 0.777374762917004
# degree 6
#
#
#
# No. of clusters 15
# lambda 5.878016072274912e-08
# loss 0.7776619196998908
# degree 6
#
#
#
# No. of clusters 15
# lambda 7.896522868499733e-08
# loss 0.7780073431558401
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.0608183551394483e-07
# loss 0.7784103731634698
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.4251026703029963e-07
# loss 0.7788661639424905
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.9144819761699575e-07
# loss 0.7793646113374961
# degree 6
#
#
#
# No. of clusters 15
# lambda 2.571913809059347e-07
# loss 0.7798909220840807
# degree 6
#
#
#
# No. of clusters 15
# lambda 3.4551072945922185e-07
# loss 0.780428093359997
# degree 6
#
#
#
# No. of clusters 15
# lambda 4.6415888336127725e-07
# loss 0.7809605219240188
# degree 6
#
#
#
# No. of clusters 15
# lambda 6.235507341273912e-07
# loss 0.7814774384700255
# degree 6
#
#
#
# No. of clusters 15
# lambda 8.376776400682924e-07
# loss 0.7819752390693013
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.1253355826007646e-06
# loss 0.7824585412911199
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.51177507061566e-06
# loss 0.7829402320048813
# degree 6
#
#
#
# No. of clusters 15
# lambda 2.030917620904735e-06
# loss 0.7834407165280106
# degree 6
# No. of clusters 15
# lambda 2.7283333764867697e-06
# loss 0.7839862579975352
# degree 6
#
#
#
# No. of clusters 15
# lambda 3.665241237079626e-06
# loss 0.7846060135429059
# degree 6
#
#
#
# No. of clusters 15
# lambda 4.923882631706732e-06
# loss 0.7853274603923143
# degree 6
#
#
#
# No. of clusters 15
# lambda 6.6147406412301455e-06
# loss 0.7861706371502596
# degree 6
#
#
#
# No. of clusters 15
# lambda 8.886238162743407e-06
# loss 0.7871427676420998
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.1937766417144358e-05
# loss 0.7882354304506434
# degree 6
#
#
#
# No. of clusters 15
# lambda 1.6037187437513277e-05
# loss 0.789425663558277
# degree 6
#
#
#
# No. of clusters 15
# lambda 2.1544346900318823e-05
# loss 0.7906807332673619
# degree 6
#
#
#
# No. of clusters 15
# lambda 2.8942661247167517e-05
# loss 0.7919651511308304
# degree 6
#
#
#
# No. of clusters 15
# lambda 3.888155180308085e-05
# loss 0.7932484353092658
# degree 6
#
#
#
# No. of clusters 15
# lambda 5.223345074266833e-05
# loss 0.794512269044303
# degree 6
#
#
#
# No. of clusters 15
# lambda 7.017038286703822e-05
# loss 0.7957554650198263
# degree 6
#
#
#
# No. of clusters 15
# lambda 9.426684551178853e-05
# loss 0.7969950188578746
# degree 6
#
#
#
# No. of clusters 15
# lambda 0.00012663801734674022
# loss 0.798262320256369
# degree 6
#
#
#
# No. of clusters 15
# lambda 0.00017012542798525856
# loss 0.7995953027526881
# degree 6
#
#
#
# No. of clusters 15
# lambda 0.00022854638641349884
# loss 0.8010292417928241
# degree 6
#
#
#
# No. of clusters 15
# lambda 0.00030702906297578496
# loss 0.8025900284465942
# degree 6
#
#
#
# No. of clusters 15
# lambda 0.00041246263829013477
# loss 0.8042930122294274
# degree 6
#
#
#
# No. of clusters 15
# lambda 0.000554102033000948
# loss 0.8061476620517573
# degree 6
#
#
#
# No. of clusters 15
# lambda 0.000744380301325168
# loss 0.8081648372547239
# degree 6
#
#
#
# No. of clusters 15
# lambda 0.001
# loss 0.8103620441542668
# degree 6
#
#
#
# No. of clusters 15
# lambda 1e-08
# loss 0.7757173327312785
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.3433993325988987e-08
# loss 0.7757339794393231
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.8047217668271702e-08
# loss 0.7757706642811626
# degree 7
#
#
#
# No. of clusters 15
# lambda 2.424462017082331e-08
# loss 0.7758325540435582
# degree 7
#
#
#
# No. of clusters 15
# lambda 3.257020655659783e-08
# loss 0.7759225682022249
# degree 7
#
#
#
# No. of clusters 15
# lambda 4.37547937507418e-08
# loss 0.7760422903296439
# degree 7
#
#
#
# No. of clusters 15
# lambda 5.878016072274912e-08
# loss 0.7761929429236798
# degree 7
#
#
#
# No. of clusters 15
# lambda 7.896522868499733e-08
# loss 0.7763760005088688
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.0608183551394483e-07
# loss 0.7765933046823004
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.4251026703029963e-07
# loss 0.7768467816168548
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.9144819761699575e-07
# loss 0.777137902496768
# degree 7
#
#
#
# No. of clusters 15
# lambda 2.571913809059347e-07
# loss 0.7774669816211017
# degree 7
#
#
#
# No. of clusters 15
# lambda 3.4551072945922185e-07
# loss 0.7778324565627288
# degree 7
#
#
#
# No. of clusters 15
# lambda 4.6415888336127725e-07
# loss 0.7782304626393055
# degree 7
#
#
#
# No. of clusters 15
# lambda 6.235507341273912e-07
# loss 0.7786550963674681
# degree 7
#
#
#
# No. of clusters 15
# lambda 8.376776400682924e-07
# loss 0.7790995448854965
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.1253355826007646e-06
# loss 0.7795578419418032
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.51177507061566e-06
# loss 0.7800267647911716
# degree 7
#
#
#
# No. of clusters 15
# lambda 2.030917620904735e-06
# loss 0.780507478234399
# degree 7
#
#
#
# No. of clusters 15
# lambda 2.7283333764867697e-06
# loss 0.7810067191364728
# degree 7
#
#
#
# No. of clusters 15
# lambda 3.665241237079626e-06
# loss 0.7815373015738083
# degree 7
#
#
#
# No. of clusters 15
# lambda 4.923882631706732e-06
# loss 0.7821175200417383
# degree 7
#
#
#
# No. of clusters 15
# lambda 6.6147406412301455e-06
# loss 0.7827689050465956
# degree 7
#
#
#
# No. of clusters 15
# lambda 8.886238162743407e-06
# loss 0.7835120756512178
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.1937766417144358e-05
# loss 0.7843613214067721
# degree 7
#
#
#
# No. of clusters 15
# lambda 1.6037187437513277e-05
# loss 0.7853196929172617
# degree 7
#
#
#
# No. of clusters 15
# lambda 2.1544346900318823e-05
# loss 0.7863768331365535
# degree 7
#
#
#
# No. of clusters 15
# lambda 2.8942661247167517e-05
# loss 0.7875108273838475
# degree 7
#
#
#
# No. of clusters 15
# lambda 3.888155180308085e-05
# loss 0.7886935746226476
# degree 7
#
#
#
# No. of clusters 15
# lambda 5.223345074266833e-05
# loss 0.789898004480773
# degree 7
#
#
#
# No. of clusters 15
# lambda 7.017038286703822e-05
# loss 0.7911054199467029
# degree 7
#
#
#
# No. of clusters 15
# lambda 9.426684551178853e-05
# loss 0.792311528914297
# degree 7
#
#
#
# No. of clusters 15
# lambda 0.00012663801734674022
# loss 0.7935296432995497
# degree 7
#
#
#
# No. of clusters 15
# lambda 0.00017012542798525856
# loss 0.7947895117654626
# degree 7
#
#
#
# No. of clusters 15
# lambda 0.00022854638641349884
# loss 0.7961311752850966
# degree 7
#
#
#
# No. of clusters 15
# lambda 0.00030702906297578496
# loss 0.7975952681251631
# degree 7
#
#
#
# No. of clusters 15
# lambda 0.00041246263829013477
# loss 0.7992134524832156
# degree 7
#
#
#
# No. of clusters 15
# lambda 0.000554102033000948
# loss 0.8010035228109157
# degree 7
#
#
#
# No. of clusters 15
# lambda 0.000744380301325168
# loss 0.802971760851185
# degree 7
#
#
#
# No. of clusters 15
# lambda 0.001
# loss 0.8051209350422803
# degree 7
#
#
#
# No. of clusters 15
# lambda 1e-08
# loss 0.7742463480922501
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.3433993325988987e-08
# loss 0.7744170271479608
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.8047217668271702e-08
# loss 0.7745729446123927
# degree 8
#
#
#
# No. of clusters 15
# lambda 2.424462017082331e-08
# loss 0.7747258993496293
# degree 8
#
#
#
# No. of clusters 15
# lambda 3.257020655659783e-08
# loss 0.774884726228687
# degree 8
#
#
#
# No. of clusters 15
# lambda 4.37547937507418e-08
# loss 0.7750549017839815
# degree 8
#
#
#
# No. of clusters 15
# lambda 5.878016072274912e-08
# loss 0.7752388278444234
# degree 8
#
#
#
# No. of clusters 15
# lambda 7.896522868499733e-08
# loss 0.7754367506551821
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.0608183551394483e-07
# loss 0.7756479849425094
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.4251026703029963e-07
# loss 0.7758719637462037
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.9144819761699575e-07
# loss 0.776108788318928
# degree 8
#
#
#
# No. of clusters 15
# lambda 2.571913809059347e-07
# loss 0.7763592712941508
# degree 8
#
#
#
# No. of clusters 15
# lambda 3.4551072945922185e-07
# loss 0.7766246959997742
# degree 8
#
#
#
# No. of clusters 15
# lambda 4.6415888336127725e-07
# loss 0.7769065433913369
# degree 8
#
#
#
# No. of clusters 15
# lambda 6.235507341273912e-07
# loss 0.7772063364019284
# degree 8
#
#
#
# No. of clusters 15
# lambda 8.376776400682924e-07
# loss 0.777525641344335
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.1253355826007646e-06
# loss 0.7778662001650047
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.51177507061566e-06
# loss 0.7782301314354767
# degree 8
#
#
#
# No. of clusters 15
# lambda 2.030917620904735e-06
# loss 0.7786201461095115
# degree 8
#
#
#
# No. of clusters 15
# lambda 2.7283333764867697e-06
# loss 0.7790398222080549
# degree 8
#
#
#
# No. of clusters 15
# lambda 3.665241237079626e-06
# loss 0.7794940945905342
# degree 8
#
#
#
# No. of clusters 15
# lambda 4.923882631706732e-06
# loss 0.7799900212565534
# degree 8
#
#
#
# No. of clusters 15
# lambda 6.6147406412301455e-06
# loss 0.7805374970453957
# degree 8
#
#
#
# No. of clusters 15
# lambda 8.886238162743407e-06
# loss 0.7811491504365237
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.1937766417144358e-05
# loss 0.781838613439731
# degree 8
#
#
#
# No. of clusters 15
# lambda 1.6037187437513277e-05
# loss 0.7826169957283025
# degree 8
#
#
#
# No. of clusters 15
# lambda 2.1544346900318823e-05
# loss 0.7834885892462642
# degree 8
#
#
#
# No. of clusters 15
# lambda 2.8942661247167517e-05
# loss 0.7844478357176937
# degree 8
#
#
#
# No. of clusters 15
# lambda 3.888155180308085e-05
# loss 0.7854794454773021
# degree 8
#
#
#
# No. of clusters 15
# lambda 5.223345074266833e-05
# loss 0.7865621217100204
# degree 8
#
#
#
# No. of clusters 15
# lambda 7.017038286703822e-05
# loss 0.7876747239339272
# degree 8
#
#
#
# No. of clusters 15
# lambda 9.426684551178853e-05
# loss 0.7888030691186024
# degree 8
#
#
#
# No. of clusters 15
# lambda 0.00012663801734674022
# loss 0.7899458135959125
# degree 8
#
#
#
# No. of clusters 15
# lambda 0.00017012542798525856
# loss 0.7911180610327595
# degree 8
#
#
#
# No. of clusters 15
# lambda 0.00022854638641349884
# loss 0.7923512464024225
# degree 8
#
#
#
# No. of clusters 15
# lambda 0.00030702906297578496
# loss 0.7936882151708177
# degree 8
#
#
#
# No. of clusters 15
# lambda 0.00041246263829013477
# loss 0.7951740083400853
# degree 8
# No. of clusters 15
# lambda 0.000554102033000948
# loss 0.7968453655284883
# degree 8
#
#
#
# No. of clusters 15
# lambda 0.000744380301325168
# loss 0.7987237220416477
# degree 8
#
#
#
# No. of clusters 15
# lambda 0.001
# loss 0.8008154747353433
# degree 8
#
#
#
# No. of clusters 25
# lambda 1e-08
# loss 0.7899485537462958
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.3433993325988987e-08
# loss 0.7898092467850979
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.8047217668271702e-08
# loss 0.789674060052889
# degree 4
#
#
#
# No. of clusters 25
# lambda 2.424462017082331e-08
# loss 0.7895530827303343
# degree 4
#
#
#
# No. of clusters 25
# lambda 3.257020655659783e-08
# loss 0.7894564623199049
# degree 4
#
#
#
# No. of clusters 25
# lambda 4.37547937507418e-08
# loss 0.7893928909647363
# degree 4
#
#
#
# No. of clusters 25
# lambda 5.878016072274912e-08
# loss 0.7893686290869475
# degree 4
#
#
#
# No. of clusters 25
# lambda 7.896522868499733e-08
# loss 0.7893876375712925
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.0608183551394483e-07
# loss 0.7894528848884683
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.4251026703029963e-07
# loss 0.7895683556295633
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.9144819761699575e-07
# loss 0.7897411229758069
# degree 4
#
#
#
# No. of clusters 25
# lambda 2.571913809059347e-07
# loss 0.7899829923253201
# degree 4
#
#
#
# No. of clusters 25
# lambda 3.4551072945922185e-07
# loss 0.7903112681387954
# degree 4
#
#
#
# No. of clusters 25
# lambda 4.6415888336127725e-07
# loss 0.7907480122019436
# degree 4
#
#
#
# No. of clusters 25
# lambda 6.235507341273912e-07
# loss 0.7913171474648887
# degree 4
#
#
#
# No. of clusters 25
# lambda 8.376776400682924e-07
# loss 0.7920394168095687
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.1253355826007646e-06
# loss 0.7929264407409684
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.51177507061566e-06
# loss 0.7939760126998101
# degree 4
#
#
#
# No. of clusters 25
# lambda 2.030917620904735e-06
# loss 0.7951703619467149
# degree 4
#
#
#
# No. of clusters 25
# lambda 2.7283333764867697e-06
# loss 0.7964776594038804
# degree 4
#
#
#
# No. of clusters 25
# lambda 3.665241237079626e-06
# loss 0.7978559497569369
# degree 4
#
#
#
# No. of clusters 25
# lambda 4.923882631706732e-06
# loss 0.7992587255572505
# degree 4
#
#
#
# No. of clusters 25
# lambda 6.6147406412301455e-06
# loss 0.8006416664146553
# degree 4
#
#
#
# No. of clusters 25
# lambda 8.886238162743407e-06
# loss 0.8019696550007349
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.1937766417144358e-05
# loss 0.8032224465053363
# degree 4
#
#
#
# No. of clusters 25
# lambda 1.6037187437513277e-05
# loss 0.8043973805375245
# degree 4
#
#
#
# No. of clusters 25
# lambda 2.1544346900318823e-05
# loss 0.8055085091170383
# degree 4
#
#
#
# No. of clusters 25
# lambda 2.8942661247167517e-05
# loss 0.806582729561913
# degree 4
#
#
#
# No. of clusters 25
# lambda 3.888155180308085e-05
# loss 0.8076542273049959
# degree 4
#
#
#
# No. of clusters 25
# lambda 5.223345074266833e-05
# loss 0.8087586640108672
# degree 4
#
#
#
# No. of clusters 25
# lambda 7.017038286703822e-05
# loss 0.8099284493561368
# degree 4
#
#
#
# No. of clusters 25
# lambda 9.426684551178853e-05
# loss 0.811190286301214
# degree 4
#
#
#
# No. of clusters 25
# lambda 0.00012663801734674022
# loss 0.8125656000136381
# degree 4
#
#
#
# No. of clusters 25
# lambda 0.00017012542798525856
# loss 0.8140730691278606
# degree 4
#
#
#
# No. of clusters 25
# lambda 0.00022854638641349884
# loss 0.8157309781921278
# degree 4
#
#
#
# No. of clusters 25
# lambda 0.00030702906297578496
# loss 0.8175571761350877
# degree 4
#
#
#
# No. of clusters 25
# lambda 0.00041246263829013477
# loss 0.819566771480807
# degree 4
#
#
#
# No. of clusters 25
# lambda 0.000554102033000948
# loss 0.8217705523728887
# degree 4
#
#
#
# No. of clusters 25
# lambda 0.000744380301325168
# loss 0.8241775244833844
# degree 4
#
#
#
# No. of clusters 25
# lambda 0.001
# loss 0.8268018895549144
# degree 4
#
#
#
# No. of clusters 25
# lambda 1e-08
# loss 0.7788297131755327
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.3433993325988987e-08
# loss 0.7791184058511533
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.8047217668271702e-08
# loss 0.779484287597321
# degree 5
#
#
#
# No. of clusters 25
# lambda 2.424462017082331e-08
# loss 0.7799247436191334
# degree 5
#
#
#
# No. of clusters 25
# lambda 3.257020655659783e-08
# loss 0.7804328007244077
# degree 5
#
#
#
# No. of clusters 25
# lambda 4.37547937507418e-08
# loss 0.7809945014070971
# degree 5
#
#
#
# No. of clusters 25
# lambda 5.878016072274912e-08
# loss 0.781588687209317
# degree 5
#
#
#
# No. of clusters 25
# lambda 7.896522868499733e-08
# loss 0.7821899171299025
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.0608183551394483e-07
# loss 0.7827734983883279
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.4251026703029963e-07
# loss 0.7833204268120599
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.9144819761699575e-07
# loss 0.7838203778854037
# degree 5
#
#
#
# No. of clusters 25
# lambda 2.571913809059347e-07
# loss 0.7842722996391267
# degree 5
#
#
#
# No. of clusters 25
# lambda 3.4551072945922185e-07
# loss 0.7846834018283174
# degree 5
#
#
#
# No. of clusters 25
# lambda 4.6415888336127725e-07
# loss 0.7850676758382222
# degree 5
#
#
#
# No. of clusters 25
# lambda 6.235507341273912e-07
# loss 0.7854446862820788
# degree 5
#
#
#
# No. of clusters 25
# lambda 8.376776400682924e-07
# loss 0.7858387796981491
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.1253355826007646e-06
# loss 0.7862783523826044
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.51177507061566e-06
# loss 0.7867944477713579
# degree 5
#
#
#
# No. of clusters 25
# lambda 2.030917620904735e-06
# loss 0.7874178594238982
# degree 5
#
#
#
# No. of clusters 25
# lambda 2.7283333764867697e-06
# loss 0.7881744335111922
# degree 5
#
#
#
# No. of clusters 25
# lambda 3.665241237079626e-06
# loss 0.789079442330887
# degree 5
#
#
#
# No. of clusters 25
# lambda 4.923882631706732e-06
# loss 0.7901330110881053
# degree 5
#
#
#
# No. of clusters 25
# lambda 6.6147406412301455e-06
# loss 0.7913185622114719
# degree 5
#
#
#
# No. of clusters 25
# lambda 8.886238162743407e-06
# loss 0.7926049684448617
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.1937766417144358e-05
# loss 0.7939517533882511
# degree 5
#
#
#
# No. of clusters 25
# lambda 1.6037187437513277e-05
# loss 0.795316233515492
# degree 5
#
#
#
# No. of clusters 25
# lambda 2.1544346900318823e-05
# loss 0.7966615123220825
# degree 5
#
#
#
# No. of clusters 25
# lambda 2.8942661247167517e-05
# loss 0.7979638690461714
# degree 5
#
#
#
# No. of clusters 25
# lambda 3.888155180308085e-05
# loss 0.7992176072596425
# degree 5
#
#
#
# No. of clusters 25
# lambda 5.223345074266833e-05
# loss 0.8004357594221728
# degree 5
#
#
#
# No. of clusters 25
# lambda 7.017038286703822e-05
# loss 0.8016463364518069
# degree 5
#
#
#
# No. of clusters 25
# lambda 9.426684551178853e-05
# loss 0.802885358208494
# degree 5
#
#
#
# No. of clusters 25
# lambda 0.00012663801734674022
# loss 0.8041890237660014
# degree 5
#
#
#
# No. of clusters 25
# lambda 0.00017012542798525856
# loss 0.8055877699137204
# degree 5
#
#
#
# No. of clusters 25
# lambda 0.00022854638641349884
# loss 0.8071043336663719
# degree 5
#
#
#
# No. of clusters 25
# lambda 0.00030702906297578496
# loss 0.8087560752989542
# degree 5
#
#
#
# No. of clusters 25
# lambda 0.00041246263829013477
# loss 0.8105594133807148
# degree 5
#
#
#
# No. of clusters 25
# lambda 0.000554102033000948
# loss 0.812533036133251
# degree 5
#
#
#
# No. of clusters 25
# lambda 0.000744380301325168
# loss 0.814697936364122
# degree 5
#
#
#
# No. of clusters 25
# lambda 0.001
# loss 0.8170754063772392
# degree 5
#
#
#
# No. of clusters 25
# lambda 1e-08
# loss 0.7765640350379399
# degree 6
#
#
#
# No. of clusters 25
# lambda 1.3433993325988987e-08
# loss 0.7766004291378387
# degree 6
#
#
#
# No. of clusters 25
# lambda 1.8047217668271702e-08
# loss 0.7766880211251403
# degree 6
#
#
#
# No. of clusters 25
# lambda 2.424462017082331e-08
# loss 0.7768264329507323
# degree 6
#
#
#
# No. of clusters 25
# lambda 3.257020655659783e-08
# loss 0.7770162031801962
# degree 6
#
#
#
# No. of clusters 25
# lambda 4.37547937507418e-08
# loss 0.7772586204655525
# degree 6
#
#
#
# No. of clusters 25
# lambda 5.878016072274912e-08
# loss 0.7775551888759298
# degree 6
#
#
#
# No. of clusters 25
# lambda 7.896522868499733e-08
# loss 0.7779066656725903
# degree 6
#
#
#
# No. of clusters 25
# lambda 1.0608183551394483e-07
# loss 0.7783116260162705
# degree 6
#
#
#
# No. of clusters 25
# lambda 1.4251026703029963e-07
# loss 0.7787648653486576
# degree 6
#
#
#
# No. of clusters 25
# lambda 1.9144819761699575e-07
# loss 0.7792564330346632
# degree 6
#
#
#
# No. of clusters 25
# lambda 2.571913809059347e-07
# loss 0.7797721855144337
# degree 6
#
#
#
# No. of clusters 25
# lambda 3.4551072945922185e-07
# loss 0.7802961142125168
# degree 6
#
#
#
# No. of clusters 25
# lambda 4.6415888336127725e-07
# loss 0.7808137222917368
# degree 6
#
#
#
# No. of clusters 25
# lambda 6.235507341273912e-07
# loss 0.7813152347447582
# degree 6
#
#
#
# No. of clusters 25
# lambda 8.376776400682924e-07
# loss 0.7817977793859247
# degree 6
# No. of clusters 25
# lambda 1.1253355826007646e-06
# loss 0.7822663803365472
# degree 6
#
#
#
# No. of clusters 25
# lambda 1.51177507061566e-06
# loss 0.7827340117623931
# degree 6
#
#
#
# No. of clusters 25
# lambda 2.030917620904735e-06
# loss 0.7832209074574713
# degree 6
#
#
#
# No. of clusters 25
# lambda 2.7283333764867697e-06
# loss 0.783753022572168
# degree 6
#
#
#
# No. of clusters 25
# lambda 3.665241237079626e-06
# loss 0.7843592589257763
# degree 6
#
#
#
# No. of clusters 25
# lambda 4.923882631706732e-06
# loss 0.7850671061509358
# degree 6
#
#
#
# No. of clusters 25
# lambda 6.6147406412301455e-06
# loss 0.7858970233832746
# degree 6
#
#
#
# No. of clusters 25
# lambda 8.886238162743407e-06
# loss 0.7868570209184189
# degree 6
#
#
#
# No. of clusters 25
# lambda 1.1937766417144358e-05
# loss 0.7879395841171339
# degree 6
#
#
#
# No. of clusters 25
# lambda 1.6037187437513277e-05
# loss 0.7891224417264981
# degree 6
#
#
#
# No. of clusters 25
# lambda 2.1544346900318823e-05
# loss 0.7903730853569744
# degree 6
#
#
#
# No. of clusters 25
# lambda 2.8942661247167517e-05
# loss 0.7916557382847543
# degree 6
#
#
#
# No. of clusters 25
# lambda 3.888155180308085e-05
# loss 0.7929392590563171
# degree 6
#
#
#
# No. of clusters 25
# lambda 5.223345074266833e-05
# loss 0.7942045408832891
# degree 6
#
#
#
# No. of clusters 25
# lambda 7.017038286703822e-05
# loss 0.7954497242829912
# degree 6
#
#
#
# No. of clusters 25
# lambda 9.426684551178853e-05
# loss 0.7966914578278402
# degree 6
#
#
#
# No. of clusters 25
# lambda 0.00012663801734674022
# loss 0.7979612623302755
# degree 6
#
#
#
# No. of clusters 25
# lambda 0.00017012542798525856
# loss 0.7992977719101855
# degree 6
#
#
#
# No. of clusters 25
# lambda 0.00022854638641349884
# loss 0.8007375342787588
# degree 6
#
#
#
# No. of clusters 25
# lambda 0.00030702906297578496
# loss 0.8023081409807004
# degree 6
#
#
#
# No. of clusters 25
# lambda 0.00041246263829013477
# loss 0.8040267138041084
# degree 6
#
#
#
# No. of clusters 25
# lambda 0.000554102033000948
# loss 0.8059039797310383
# degree 6
#
#
#
# No. of clusters 25
# lambda 0.000744380301325168
# loss 0.8079508495400043
# degree 6
#
#
#
# No. of clusters 25
# lambda 0.001
# loss 0.8101831834160149
# degree 6
#
#
#
# No. of clusters 25
# lambda 1e-08
# loss 0.7755368460543937
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.3433993325988987e-08
# loss 0.7755541673680408
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.8047217668271702e-08
# loss 0.7755938296064129
# degree 7
#
#
#
# No. of clusters 25
# lambda 2.424462017082331e-08
# loss 0.7756609559819365
# degree 7
#
#
#
# No. of clusters 25
# lambda 3.257020655659783e-08
# loss 0.7757581925491088
# degree 7
#
#
#
# No. of clusters 25
# lambda 4.37547937507418e-08
# loss 0.7758866721606632
# degree 7
#
#
#
# No. of clusters 25
# lambda 5.878016072274912e-08
# loss 0.7760470382266902
# degree 7
#
#
#
# No. of clusters 25
# lambda 7.896522868499733e-08
# loss 0.7762400913965498
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.0608183551394483e-07
# loss 0.7764669324891365
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.4251026703029963e-07
# loss 0.7767287177471576
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.9144819761699575e-07
# loss 0.7770261795480674
# degree 7
#
#
#
# No. of clusters 25
# lambda 2.571913809059347e-07
# loss 0.7773590128304791
# degree 7
#
#
#
# No. of clusters 25
# lambda 3.4551072945922185e-07
# loss 0.7777252620188915
# degree 7
#
#
#
# No. of clusters 25
# lambda 4.6415888336127725e-07
# loss 0.7781209888557108
# degree 7
#
#
#
# No. of clusters 25
# lambda 6.235507341273912e-07
# loss 0.7785405698879749
# degree 7
#
#
#
# No. of clusters 25
# lambda 8.376776400682924e-07
# loss 0.7789777673326003
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.1253355826007646e-06
# loss 0.77942733920259
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.51177507061566e-06
# loss 0.7798867466862006
# degree 7
#
#
#
# No. of clusters 25
# lambda 2.030917620904735e-06
# loss 0.7803576219196413
# degree 7
#
#
#
# No. of clusters 25
# lambda 2.7283333764867697e-06
# loss 0.7808468364745849
# degree 7
#
#
#
# No. of clusters 25
# lambda 3.665241237079626e-06
# loss 0.7813669855107096
# degree 7
#
#
#
# No. of clusters 25
# lambda 4.923882631706732e-06
# loss 0.7819358923372265
# degree 7
#
#
#
# No. of clusters 25
# lambda 6.6147406412301455e-06
# loss 0.7825745914547488
# degree 7
#
#
#
# No. of clusters 25
# lambda 8.886238162743407e-06
# loss 0.7833034782921735
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.1937766417144358e-05
# loss 0.7841371278480732
# degree 7
#
#
#
# No. of clusters 25
# lambda 1.6037187437513277e-05
# loss 0.7850794137728612
# degree 7
#
#
#
# No. of clusters 25
# lambda 2.1544346900318823e-05
# loss 0.7861211051420384
# degree 7
#
#
#
# No. of clusters 25
# lambda 2.8942661247167517e-05
# loss 0.7872413236287836
# degree 7
#
#
#
# No. of clusters 25
# lambda 3.888155180308085e-05
# loss 0.7884125673054514
# degree 7
#
#
#
# No. of clusters 25
# lambda 5.223345074266833e-05
# loss 0.7896077862844524
# degree 7
#
#
#
# No. of clusters 25
# lambda 7.017038286703822e-05
# loss 0.7908078186534683
# degree 7
#
#
#
# No. of clusters 25
# lambda 9.426684551178853e-05
# loss 0.7920076731336384
# degree 7
#
#
#
# No. of clusters 25
# lambda 0.00012663801734674022
# loss 0.7932200397801014
# degree 7
#
#
#
# No. of clusters 25
# lambda 0.00017012542798525856
# loss 0.7944744317385133
# degree 7
#
#
#
# No. of clusters 25
# lambda 0.00022854638641349884
# loss 0.7958113123362007
# degree 7
#
#
#
# No. of clusters 25
# lambda 0.00030702906297578496
# loss 0.7972725789375078
# degree 7
#
#
#
# No. of clusters 25
# lambda 0.00041246263829013477
# loss 0.7988919871539617
# degree 7
#
#
#
# No. of clusters 25
# lambda 0.000554102033000948
# loss 0.800689911170043
# degree 7
#
#
#
# No. of clusters 25
# lambda 0.000744380301325168
# loss 0.8026749486089667
# degree 7
#
#
#
# No. of clusters 25
# lambda 0.001
# loss 0.8048509084491814
# degree 7
#
#
#
# No. of clusters 25
# lambda 1e-08
# loss 0.7741158596394413
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.3433993325988987e-08
# loss 0.7742770255970401
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.8047217668271702e-08
# loss 0.7744249018431077
# degree 8
#
#
#
# No. of clusters 25
# lambda 2.424462017082331e-08
# loss 0.774571565571674
# degree 8
#
#
#
# No. of clusters 25
# lambda 3.257020655659783e-08
# loss 0.7747261911364933
# degree 8
#
#
#
# No. of clusters 25
# lambda 4.37547937507418e-08
# loss 0.7748944666407046
# degree 8
#
#
#
# No. of clusters 25
# lambda 5.878016072274912e-08
# loss 0.7750787766204935
# degree 8
#
#
#
# No. of clusters 25
# lambda 7.896522868499733e-08
# loss 0.7752791162018647
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.0608183551394483e-07
# loss 0.7754943695229374
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.4251026703029963e-07
# loss 0.7757234291074491
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.9144819761699575e-07
# loss 0.7759658063650227
# degree 8
#
#
#
# No. of clusters 25
# lambda 2.571913809059347e-07
# loss 0.7762217233065322
# degree 8
#
#
#
# No. of clusters 25
# lambda 3.4551072945922185e-07
# loss 0.7764919154173284
# degree 8
#
#
#
# No. of clusters 25
# lambda 4.6415888336127725e-07
# loss 0.7767774056235696
# degree 8
#
#
#
# No. of clusters 25
# lambda 6.235507341273912e-07
# loss 0.7770794024670995
# degree 8
#
#
#
# No. of clusters 25
# lambda 8.376776400682924e-07
# loss 0.777399353351802
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.1253355826007646e-06
# loss 0.7777391034564556
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.51177507061566e-06
# loss 0.7781010697356335
# degree 8
#
#
#
# No. of clusters 25
# lambda 2.030917620904735e-06
# loss 0.7784883607157689
# degree 8
#
#
#
# No. of clusters 25
# lambda 2.7283333764867697e-06
# loss 0.7789048989345247
# degree 8
#
#
#
# No. of clusters 25
# lambda 3.665241237079626e-06
# loss 0.7793557437174903
# degree 8
#
#
#
# No. of clusters 25
# lambda 4.923882631706732e-06
# loss 0.7798477355752299
# degree 8
#
#
#
# No. of clusters 25
# lambda 6.6147406412301455e-06
# loss 0.7803901966398652
# degree 8
#
#
#
# No. of clusters 25
# lambda 8.886238162743407e-06
# loss 0.7809949683551956
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.1937766417144358e-05
# loss 0.7816749681679045
# degree 8
#
#
#
# No. of clusters 25
# lambda 1.6037187437513277e-05
# loss 0.7824410014942104
# degree 8
#
#
#
# No. of clusters 25
# lambda 2.1544346900318823e-05
# loss 0.7832976890905973
# degree 8
#
#
#
# No. of clusters 25
# lambda 2.8942661247167517e-05
# loss 0.7842403957188135
# degree 8
#
#
#
# No. of clusters 25
# lambda 3.888155180308085e-05
# loss 0.785255036560366
# degree 8
#
#
#
# No. of clusters 25
# lambda 5.223345074266833e-05
# loss 0.7863213685364219
# degree 8
#
#
#
# No. of clusters 25
# lambda 7.017038286703822e-05
# loss 0.7874188182323862
# degree 8
#
#
#
# No. of clusters 25
# lambda 9.426684551178853e-05
# loss 0.788533185425847
# degree 8
#
#
#
# No. of clusters 25
# lambda 0.00012663801734674022
# loss 0.7896626710688086
# degree 8
#
#
#
# No. of clusters 25
# lambda 0.00017012542798525856
# loss 0.790821796051685
# degree 8
# No. of clusters 25
# lambda 0.00022854638641349884
# loss 0.7920416757444512
# degree 8
#
#
#
# No. of clusters 25
# lambda 0.00030702906297578496
# loss 0.7933655055743541
# degree 8
#
#
#
# No. of clusters 25
# lambda 0.00041246263829013477
# loss 0.7948396868121045
# degree 8
#
#
#
# No. of clusters 25
# lambda 0.000554102033000948
# loss 0.7965034507103936
# degree 8
#
#
#
# No. of clusters 25
# lambda 0.000744380301325168
# loss 0.7983815413260976
# degree 8
#
#
#
# No. of clusters 25
# lambda 0.001
# loss 0.8004835952630911
# degree 8
#
#
#
# No. of clusters 35
# lambda 1e-08
# loss 0.7902303157829563
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.3433993325988987e-08
# loss 0.7900944346979044
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.8047217668271702e-08
# loss 0.7899622103925376
# degree 4
#
#
#
# No. of clusters 35
# lambda 2.424462017082331e-08
# loss 0.789843172544898
# degree 4
#
#
#
# No. of clusters 35
# lambda 3.257020655659783e-08
# loss 0.7897469093863259
# degree 4
#
#
#
# No. of clusters 35
# lambda 4.37547937507418e-08
# loss 0.7896817051473003
# degree 4
#
#
#
# No. of clusters 35
# lambda 5.878016072274912e-08
# loss 0.7896536978497103
# degree 4
#
#
#
# No. of clusters 35
# lambda 7.896522868499733e-08
# loss 0.7896670635306303
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.0608183551394483e-07
# loss 0.7897252591787136
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.4251026703029963e-07
# loss 0.7898328684863775
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.9144819761699575e-07
# loss 0.7899974745279493
# degree 4
#
#
#
# No. of clusters 35
# lambda 2.571913809059347e-07
# loss 0.7902311429815879
# degree 4
#
#
#
# No. of clusters 35
# lambda 3.4551072945922185e-07
# loss 0.7905511276498257
# degree 4
#
#
#
# No. of clusters 35
# lambda 4.6415888336127725e-07
# loss 0.790979187343701
# degree 4
#
#
#
# No. of clusters 35
# lambda 6.235507341273912e-07
# loss 0.791538845170289
# degree 4
#
#
#
# No. of clusters 35
# lambda 8.376776400682924e-07
# loss 0.792250542028494
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.1253355826007646e-06
# loss 0.7931258551065559
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.51177507061566e-06
# loss 0.7941628570517372
# degree 4
#
#
#
# No. of clusters 35
# lambda 2.030917620904735e-06
# loss 0.7953443210000126
# degree 4
#
#
#
# No. of clusters 35
# lambda 2.7283333764867697e-06
# loss 0.796639075459302
# degree 4
#
#
#
# No. of clusters 35
# lambda 3.665241237079626e-06
# loss 0.7980057599081001
# degree 4
#
#
#
# No. of clusters 35
# lambda 4.923882631706732e-06
# loss 0.7993982644727021
# degree 4
#
#
#
# No. of clusters 35
# lambda 6.6147406412301455e-06
# loss 0.800772409436185
# degree 4
#
#
#
# No. of clusters 35
# lambda 8.886238162743407e-06
# loss 0.8020929670153615
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.1937766417144358e-05
# loss 0.8033393710089773
# degree 4
#
#
#
# No. of clusters 35
# lambda 1.6037187437513277e-05
# loss 0.804508478664831
# degree 4
#
#
#
# No. of clusters 35
# lambda 2.1544346900318823e-05
# loss 0.805613757112232
# degree 4
#
#
#
# No. of clusters 35
# lambda 2.8942661247167517e-05
# loss 0.8066815018446885
# degree 4
#
#
#
# No. of clusters 35
# lambda 3.888155180308085e-05
# loss 0.8077454096805983
# degree 4
#
#
#
# No. of clusters 35
# lambda 5.223345074266833e-05
# loss 0.808840930352193
# degree 4
#
#
#
# No. of clusters 35
# lambda 7.017038286703822e-05
# loss 0.8100006801456369
# degree 4
#
#
#
# No. of clusters 35
# lambda 9.426684551178853e-05
# loss 0.8112520244866379
# degree 4
#
#
#
# No. of clusters 35
# lambda 0.00012663801734674022
# loss 0.8126173766263076
# degree 4
#
#
#
# No. of clusters 35
# lambda 0.00017012542798525856
# loss 0.8141164373328935
# degree 4
#
#
#
# No. of clusters 35
# lambda 0.00022854638641349884
# loss 0.8157681815970499
# degree 4
#
#
#
# No. of clusters 35
# lambda 0.00030702906297578496
# loss 0.8175905175494952
# degree 4
#
#
#
# No. of clusters 35
# lambda 0.00041246263829013477
# loss 0.8195978981480241
# degree 4
#
#
#
# No. of clusters 35
# lambda 0.000554102033000948
# loss 0.821799969038873
# degree 4
#
#
#
# No. of clusters 35
# lambda 0.000744380301325168
# loss 0.8242045984174083
# degree 4
#
#
#
# No. of clusters 35
# lambda 0.001
# loss 0.826825386087676
# degree 4
#
#
#
# No. of clusters 35
# lambda 1e-08
# loss 0.77882410469767
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.3433993325988987e-08
# loss 0.7791275450385583
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.8047217668271702e-08
# loss 0.7795092175836117
# degree 5
#
#
#
# No. of clusters 35
# lambda 2.424462017082331e-08
# loss 0.7799672832911547
# degree 5
#
#
#
# No. of clusters 35
# lambda 3.257020655659783e-08
# loss 0.7804950620818699
# degree 5
#
#
#
# No. of clusters 35
# lambda 4.37547937507418e-08
# loss 0.7810782636775924
# degree 5
#
#
#
# No. of clusters 35
# lambda 5.878016072274912e-08
# loss 0.7816947959096772
# degree 5
#
#
#
# No. of clusters 35
# lambda 7.896522868499733e-08
# loss 0.7823178895432461
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.0608183551394483e-07
# loss 0.7829214476076503
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.4251026703029963e-07
# loss 0.7834853073947876
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.9144819761699575e-07
# loss 0.7839984661717846
# degree 5
#
#
#
# No. of clusters 35
# lambda 2.571913809059347e-07
# loss 0.7844597743915063
# degree 5
#
#
#
# No. of clusters 35
# lambda 3.4551072945922185e-07
# loss 0.7848768806787402
# degree 5
#
#
#
# No. of clusters 35
# lambda 4.6415888336127725e-07
# loss 0.7852645830471385
# degree 5
#
#
#
# No. of clusters 35
# lambda 6.235507341273912e-07
# loss 0.785643377679794
# degree 5
#
#
#
# No. of clusters 35
# lambda 8.376776400682924e-07
# loss 0.7860384237725833
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.1253355826007646e-06
# loss 0.786478639278254
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.51177507061566e-06
# loss 0.7869952423718436
# degree 5
#
#
#
# No. of clusters 35
# lambda 2.030917620904735e-06
# loss 0.7876189157482096
# degree 5
#
#
#
# No. of clusters 35
# lambda 2.7283333764867697e-06
# loss 0.7883752512447117
# degree 5
#
#
#
# No. of clusters 35
# lambda 3.665241237079626e-06
# loss 0.7892792884676851
# degree 5
#
#
#
# No. of clusters 35
# lambda 4.923882631706732e-06
# loss 0.7903310650779769
# degree 5
#
#
#
# No. of clusters 35
# lambda 6.6147406412301455e-06
# loss 0.7915140909596313
# degree 5
#
#
#
# No. of clusters 35
# lambda 8.886238162743407e-06
# loss 0.7927974277673899
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.1937766417144358e-05
# loss 0.7941407606248629
# degree 5
#
#
#
# No. of clusters 35
# lambda 1.6037187437513277e-05
# loss 0.7955014311928709
# degree 5
#
#
#
# No. of clusters 35
# lambda 2.1544346900318823e-05
# loss 0.7968423873888156
# degree 5
#
#
#
# No. of clusters 35
# lambda 2.8942661247167517e-05
# loss 0.7981395831964911
# degree 5
#
#
#
# No. of clusters 35
# lambda 3.888155180308085e-05
# loss 0.7993868657223009
# degree 5
#
#
#
# No. of clusters 35
# lambda 5.223345074266833e-05
# loss 0.8005967443411663
# degree 5
#
#
#
# No. of clusters 35
# lambda 7.017038286703822e-05
# loss 0.8017967601242223
# degree 5
#
#
#
# No. of clusters 35
# lambda 9.426684551178853e-05
# loss 0.8030227083545164
# degree 5
#
#
#
# No. of clusters 35
# lambda 0.00012663801734674022
# loss 0.8043110289551463
# degree 5
#
#
#
# No. of clusters 35
# lambda 0.00017012542798525856
# loss 0.8056930003454396
# degree 5
#
#
#
# No. of clusters 35
# lambda 0.00022854638641349884
# loss 0.8071927266238138
# degree 5
#
#
#
# No. of clusters 35
# lambda 0.00030702906297578496
# loss 0.8088291285426299
# degree 5
#
#
#
# No. of clusters 35
# lambda 0.00041246263829013477
# loss 0.8106198825282341
# degree 5
#
#
#
# No. of clusters 35
# lambda 0.000554102033000948
# loss 0.8125841791410051
# degree 5
#
#
#
# No. of clusters 35
# lambda 0.000744380301325168
# loss 0.8147425783166892
# degree 5
#
#
#
# No. of clusters 35
# lambda 0.001
# loss 0.8171152335904495
# degree 5
#
#
#
# No. of clusters 35
# lambda 1e-08
# loss 0.7764935075798833
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.3433993325988987e-08
# loss 0.7765404483524563
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.8047217668271702e-08
# loss 0.7766371980871669
# degree 6
#
#
#
# No. of clusters 35
# lambda 2.424462017082331e-08
# loss 0.776783502684861
# degree 6
#
#
#
# No. of clusters 35
# lambda 3.257020655659783e-08
# loss 0.7769803079844853
# degree 6
#
#
#
# No. of clusters 35
# lambda 4.37547937507418e-08
# loss 0.7772295527804786
# degree 6
#
#
#
# No. of clusters 35
# lambda 5.878016072274912e-08
# loss 0.7775335511104126
# degree 6
#
#
#
# No. of clusters 35
# lambda 7.896522868499733e-08
# loss 0.7778938872045573
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.0608183551394483e-07
# loss 0.7783097842144806
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.4251026703029963e-07
# loss 0.7787763013142762
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.9144819761699575e-07
# loss 0.7792832327233512
# degree 6
#
#
#
# No. of clusters 35
# lambda 2.571913809059347e-07
# loss 0.7798156780552731
# degree 6
#
#
#
# No. of clusters 35
# lambda 3.4551072945922185e-07
# loss 0.7803565646532158
# degree 6
# No. of clusters 35
# lambda 4.6415888336127725e-07
# loss 0.7808903323787214
# degree 6
#
#
#
# No. of clusters 35
# lambda 6.235507341273912e-07
# loss 0.7814064408388913
# degree 6
#
#
#
# No. of clusters 35
# lambda 8.376776400682924e-07
# loss 0.781901720662852
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.1253355826007646e-06
# loss 0.7823813604261285
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.51177507061566e-06
# loss 0.7828588058230874
# degree 6
#
#
#
# No. of clusters 35
# lambda 2.030917620904735e-06
# loss 0.7833548483431417
# degree 6
#
#
#
# No. of clusters 35
# lambda 2.7283333764867697e-06
# loss 0.783895890383787
# degree 6
#
#
#
# No. of clusters 35
# lambda 3.665241237079626e-06
# loss 0.7845110587220603
# degree 6
#
#
#
# No. of clusters 35
# lambda 4.923882631706732e-06
# loss 0.7852278331794054
# degree 6
#
#
#
# No. of clusters 35
# lambda 6.6147406412301455e-06
# loss 0.7860664934880168
# degree 6
#
#
#
# No. of clusters 35
# lambda 8.886238162743407e-06
# loss 0.787034801700891
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.1937766417144358e-05
# loss 0.7881250092663442
# degree 6
#
#
#
# No. of clusters 35
# lambda 1.6037187437513277e-05
# loss 0.789314644090785
# degree 6
#
#
#
# No. of clusters 35
# lambda 2.1544346900318823e-05
# loss 0.7905709775329571
# degree 6
#
#
#
# No. of clusters 35
# lambda 2.8942661247167517e-05
# loss 0.7918579163930051
# degree 6
#
#
#
# No. of clusters 35
# lambda 3.888155180308085e-05
# loss 0.793143866429345
# degree 6
#
#
#
# No. of clusters 35
# lambda 5.223345074266833e-05
# loss 0.7944091505001917
# degree 6
#
#
#
# No. of clusters 35
# lambda 7.017038286703822e-05
# loss 0.795651281896879
# degree 6
#
#
#
# No. of clusters 35
# lambda 9.426684551178853e-05
# loss 0.7968863184115568
# degree 6
#
#
#
# No. of clusters 35
# lambda 0.00012663801734674022
# loss 0.7981453735482286
# degree 6
#
#
#
# No. of clusters 35
# lambda 0.00017012542798525856
# loss 0.7994670714892792
# degree 6
#
#
#
# No. of clusters 35
# lambda 0.00022854638641349884
# loss 0.8008885721293229
# degree 6
#
#
#
# No. of clusters 35
# lambda 0.00030702906297578496
# loss 0.8024387995048375
# degree 6
#
#
#
# No. of clusters 35
# lambda 0.00041246263829013477
# loss 0.8041367569649672
# degree 6
#
#
#
# No. of clusters 35
# lambda 0.000554102033000948
# loss 0.8059951357939786
# degree 6
#
#
#
# No. of clusters 35
# lambda 0.000744380301325168
# loss 0.8080262905262809
# degree 6
#
#
#
# No. of clusters 35
# lambda 0.001
# loss 0.8102465486075173
# degree 6
#
#
#
# No. of clusters 35
# lambda 1e-08
# loss 0.7754814222885479
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.3433993325988987e-08
# loss 0.7755033312501793
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.8047217668271702e-08
# loss 0.775548094767208
# degree 7
#
#
#
# No. of clusters 35
# lambda 2.424462017082331e-08
# loss 0.7756201314964811
# degree 7
#
#
#
# No. of clusters 35
# lambda 3.257020655659783e-08
# loss 0.7757216144029478
# degree 7
#
#
#
# No. of clusters 35
# lambda 4.37547937507418e-08
# loss 0.7758534552405589
# degree 7
#
#
#
# No. of clusters 35
# lambda 5.878016072274912e-08
# loss 0.7760163129534956
# degree 7
#
#
#
# No. of clusters 35
# lambda 7.896522868499733e-08
# loss 0.7762112160043995
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.0608183551394483e-07
# loss 0.7764396775334116
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.4251026703029963e-07
# loss 0.7767034059747739
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.9144819761699575e-07
# loss 0.7770037468724992
# degree 7
#
#
#
# No. of clusters 35
# lambda 2.571913809059347e-07
# loss 0.7773409506784363
# degree 7
#
#
#
# No. of clusters 35
# lambda 3.4551072945922185e-07
# loss 0.7777134208947156
# degree 7
#
#
#
# No. of clusters 35
# lambda 4.6415888336127725e-07
# loss 0.7781172716981206
# degree 7
#
#
#
# No. of clusters 35
# lambda 6.235507341273912e-07
# loss 0.7785466039060862
# degree 7
#
#
#
# No. of clusters 35
# lambda 8.376776400682924e-07
# loss 0.778994674230827
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.1253355826007646e-06
# loss 0.779455692023846
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.51177507061566e-06
# loss 0.7799267167314634
# degree 7
#
#
#
# No. of clusters 35
# lambda 2.030917620904735e-06
# loss 0.7804092334217706
# degree 7
#
#
#
# No. of clusters 35
# lambda 2.7283333764867697e-06
# loss 0.7809102110838612
# degree 7
#
#
#
# No. of clusters 35
# lambda 3.665241237079626e-06
# loss 0.7814424847472927
# degree 7
#
#
#
# No. of clusters 35
# lambda 4.923882631706732e-06
# loss 0.7820241260403954
# degree 7
#
#
#
# No. of clusters 35
# lambda 6.6147406412301455e-06
# loss 0.7826763150183351
# degree 7
#
#
#
# No. of clusters 35
# lambda 8.886238162743407e-06
# loss 0.7834194296239526
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.1937766417144358e-05
# loss 0.7842678584534738
# degree 7
#
#
#
# No. of clusters 35
# lambda 1.6037187437513277e-05
# loss 0.7852251543005224
# degree 7
#
#
#
# No. of clusters 35
# lambda 2.1544346900318823e-05
# loss 0.7862816742775768
# degree 7
#
#
#
# No. of clusters 35
# lambda 2.8942661247167517e-05
# loss 0.787416051157112
# degree 7
#
#
#
# No. of clusters 35
# lambda 3.888155180308085e-05
# loss 0.7886001907929245
# degree 7
#
#
#
# No. of clusters 35
# lambda 5.223345074266833e-05
# loss 0.789806315331335
# degree 7
#
#
#
# No. of clusters 35
# lambda 7.017038286703822e-05
# loss 0.7910144093730967
# degree 7
#
#
#
# No. of clusters 35
# lambda 9.426684551178853e-05
# loss 0.7922185719067731
# degree 7
#
#
#
# No. of clusters 35
# lambda 0.00012663801734674022
# loss 0.7934306406823727
# degree 7
#
#
#
# No. of clusters 35
# lambda 0.00017012542798525856
# loss 0.7946794856341359
# degree 7
#
#
#
# No. of clusters 35
# lambda 0.00022854638641349884
# loss 0.7960053367189537
# degree 7
#
#
#
# No. of clusters 35
# lambda 0.00030702906297578496
# loss 0.7974504983870336
# degree 7
#
#
#
# No. of clusters 35
# lambda 0.00041246263829013477
# loss 0.7990499336927088
# degree 7
#
#
#
# No. of clusters 35
# lambda 0.000554102033000948
# loss 0.8008259567673482
# degree 7
#
#
#
# No. of clusters 35
# lambda 0.000744380301325168
# loss 0.8027894460840892
# degree 7
#
#
#
# No. of clusters 35
# lambda 0.001
# loss 0.8049462046265516
# degree 7
#
#
#
# No. of clusters 35
# lambda 1e-08
# loss 0.7740983706425598
# degree 8
#
#
#
# No. of clusters 35
# lambda 1.3433993325988987e-08
# loss 0.774258789789188
# degree 8
#
#
#
# No. of clusters 35
# lambda 1.8047217668271702e-08
# loss 0.7744075643382763
# degree 8
#
#
#
# No. of clusters 35
# lambda 2.424462017082331e-08
# loss 0.7745562699854982
# degree 8
#
#
#
# No. of clusters 35
# lambda 3.257020655659783e-08
# loss 0.7747134651771992
# degree 8
#
#
#
# No. of clusters 35
# lambda 4.37547937507418e-08
# loss 0.7748842417843479
# degree 8
#
#
#
# No. of clusters 35
# lambda 5.878016072274912e-08
# loss 0.7750705182061612
# degree 8
#
#
#
# No. of clusters 35
# lambda 7.896522868499733e-08
# loss 0.7752720118781767
# degree 8
#
#
#
# No. of clusters 35
# lambda 1.0608183551394483e-07
# loss 0.7754875251787918
# degree 8
#
#
#
# No. of clusters 35
# lambda 1.4251026703029963e-07
# loss 0.775716044133125
# degree 8
#
#
#
# No. of clusters 35
# lambda 1.9144819761699575e-07
# loss 0.77595732088566
# degree 8
#
#
#
# No. of clusters 35
# lambda 2.571913809059347e-07
# loss 0.7762119345847571
# degree 8
#
#
#
# No. of clusters 35
# lambda 3.4551072945922185e-07
# loss 0.7764810525787066
# degree 8
#
#
#
# No. of clusters 35
# lambda 4.6415888336127725e-07
# loss 0.776766143926225
# degree 8
#
#
#
# No. of clusters 35
# lambda 6.235507341273912e-07
# loss 0.7770688017240621
# degree 8
#
#
#
# No. of clusters 35
# ...
# loss 0.7827379485370929
# degree 8
#
#
#
# No. of clusters 95
# lambda 2.1544346900318823e-05
# loss 0.783617745683497
# degree 8
#
#
#
# No. of clusters 95
# lambda 2.8942661247167517e-05
# loss 0.78458348784848
# degree 8
#
#
#
# No. of clusters 95
# lambda 3.888155180308085e-05
# loss 0.7856207841906008
# degree 8
#
#
#
# No. of clusters 95
# lambda 5.223345074266833e-05
# loss 0.7867088398142588
# degree 8
#
#
#
# No. of clusters 95
# lambda 7.017038286703822e-05
# loss 0.7878260794769002
# degree 8
#
#
#
# No. of clusters 95
# lambda 9.426684551178853e-05
# loss 0.7889567507185846
# degree 8
#
#
#
# No. of clusters 95
# lambda 0.00012663801734674022
# loss 0.7900970281521794
# degree 8
#
#
#
# No. of clusters 95
# lambda 0.00017012542798525856
# loss 0.7912591748172233
# degree 8
#
#
#
# No. of clusters 95
# lambda 0.00022854638641349884
# loss 0.7924722014928332
# degree 8
#
#
#
# No. of clusters 95
# lambda 0.00030702906297578496
# loss 0.7937778953407586
# degree 8
#
#
#
# No. of clusters 95
# lambda 0.00041246263829013477
# loss 0.7952226231689222
# degree 8
#
#
#
# No. of clusters 95
# lambda 0.000554102033000948
# loss 0.7968475441075847
# degree 8
#
#
#
# No. of clusters 95
# lambda 0.000744380301325168
# loss 0.7986813486196482
# degree 8
#
#
#
# No. of clusters 95
# lambda 0.001
# loss 0.800738784831359
# degree 8
# E:\ML_course\ML_course\projects\project1\scripts\preprocess.py:86: RuntimeWarning: invalid value encountered in true_divide
#   center = np.matmul(np.transpose(one_hot2, (1, 0)), data) / np.expand_dims(np.sum(one_hot2, axis=0), axis=1)
# D:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# D:\Anaconda\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# No. of clusters 105
# lambda 1e-08
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.3433993325988987e-08
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.8047217668271702e-08
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 2.424462017082331e-08
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 3.257020655659783e-08
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 4.37547937507418e-08
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 5.878016072274912e-08
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 7.896522868499733e-08
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.0608183551394483e-07
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.4251026703029963e-07
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.9144819761699575e-07
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 2.571913809059347e-07
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 3.4551072945922185e-07
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 4.6415888336127725e-07
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 6.235507341273912e-07
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 8.376776400682924e-07
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.1253355826007646e-06
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.51177507061566e-06
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 2.030917620904735e-06
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 2.7283333764867697e-06
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 3.665241237079626e-06
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 4.923882631706732e-06
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 6.6147406412301455e-06
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 8.886238162743407e-06
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.1937766417144358e-05
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1.6037187437513277e-05
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 2.1544346900318823e-05
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 2.8942661247167517e-05
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 3.888155180308085e-05
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 5.223345074266833e-05
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 7.017038286703822e-05
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 9.426684551178853e-05
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 0.00012663801734674022
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 0.00017012542798525856
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 0.00022854638641349884
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 0.00030702906297578496
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 0.00041246263829013477
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 0.000554102033000948
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 0.000744380301325168
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 0.001
# loss nan
# degree 4
#
#
#
# No. of clusters 105
# lambda 1e-08
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.3433993325988987e-08
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.8047217668271702e-08
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 2.424462017082331e-08
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 3.257020655659783e-08
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 4.37547937507418e-08
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 5.878016072274912e-08
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 7.896522868499733e-08
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.0608183551394483e-07
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.4251026703029963e-07
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.9144819761699575e-07
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 2.571913809059347e-07
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 3.4551072945922185e-07
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 4.6415888336127725e-07
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 6.235507341273912e-07
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 8.376776400682924e-07
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.1253355826007646e-06
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.51177507061566e-06
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 2.030917620904735e-06
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 2.7283333764867697e-06
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 3.665241237079626e-06
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 4.923882631706732e-06
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 6.6147406412301455e-06
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 8.886238162743407e-06
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.1937766417144358e-05
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1.6037187437513277e-05
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 2.1544346900318823e-05
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 2.8942661247167517e-05
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 3.888155180308085e-05
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 5.223345074266833e-05
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 7.017038286703822e-05
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 9.426684551178853e-05
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 0.00012663801734674022
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 0.00017012542798525856
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 0.00022854638641349884
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 0.00030702906297578496
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 0.00041246263829013477
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 0.000554102033000948
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 0.000744380301325168
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 0.001
# loss nan
# degree 5
#
#
#
# No. of clusters 105
# lambda 1e-08
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.3433993325988987e-08
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.8047217668271702e-08
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 2.424462017082331e-08
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 3.257020655659783e-08
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 4.37547937507418e-08
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 5.878016072274912e-08
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 7.896522868499733e-08
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.0608183551394483e-07
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.4251026703029963e-07
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.9144819761699575e-07
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 2.571913809059347e-07
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 3.4551072945922185e-07
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 4.6415888336127725e-07
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 6.235507341273912e-07
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 8.376776400682924e-07
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.1253355826007646e-06
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.51177507061566e-06
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 2.030917620904735e-06
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 2.7283333764867697e-06
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 3.665241237079626e-06
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 4.923882631706732e-06
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 6.6147406412301455e-06
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 8.886238162743407e-06
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.1937766417144358e-05
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1.6037187437513277e-05
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 2.1544346900318823e-05
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 2.8942661247167517e-05
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 3.888155180308085e-05
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 5.223345074266833e-05
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 7.017038286703822e-05
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 9.426684551178853e-05
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 0.00012663801734674022
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 0.00017012542798525856
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 0.00022854638641349884
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 0.00030702906297578496
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 0.00041246263829013477
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 0.000554102033000948
# loss nan
# degree 6
# No. of clusters 105
# lambda 0.000744380301325168
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 0.001
# loss nan
# degree 6
#
#
#
# No. of clusters 105
# lambda 1e-08
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.3433993325988987e-08
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.8047217668271702e-08
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 2.424462017082331e-08
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 3.257020655659783e-08
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 4.37547937507418e-08
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 5.878016072274912e-08
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 7.896522868499733e-08
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.0608183551394483e-07
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.4251026703029963e-07
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.9144819761699575e-07
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 2.571913809059347e-07
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 3.4551072945922185e-07
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 4.6415888336127725e-07
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 6.235507341273912e-07
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 8.376776400682924e-07
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.1253355826007646e-06
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.51177507061566e-06
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 2.030917620904735e-06
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 2.7283333764867697e-06
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 3.665241237079626e-06
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 4.923882631706732e-06
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 6.6147406412301455e-06
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 8.886238162743407e-06
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.1937766417144358e-05
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1.6037187437513277e-05
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 2.1544346900318823e-05
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 2.8942661247167517e-05
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 3.888155180308085e-05
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 5.223345074266833e-05
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 7.017038286703822e-05
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 9.426684551178853e-05
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 0.00012663801734674022
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 0.00017012542798525856
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 0.00022854638641349884
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 0.00030702906297578496
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 0.00041246263829013477
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 0.000554102033000948
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 0.000744380301325168
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 0.001
# loss nan
# degree 7
#
#
#
# No. of clusters 105
# lambda 1e-08
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.3433993325988987e-08
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.8047217668271702e-08
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 2.424462017082331e-08
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 3.257020655659783e-08
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 4.37547937507418e-08
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 5.878016072274912e-08
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 7.896522868499733e-08
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.0608183551394483e-07
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.4251026703029963e-07
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.9144819761699575e-07
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 2.571913809059347e-07
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 3.4551072945922185e-07
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 4.6415888336127725e-07
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 6.235507341273912e-07
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 8.376776400682924e-07
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.1253355826007646e-06
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.51177507061566e-06
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 2.030917620904735e-06
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 2.7283333764867697e-06
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 3.665241237079626e-06
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 4.923882631706732e-06
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 6.6147406412301455e-06
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 8.886238162743407e-06
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.1937766417144358e-05
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 1.6037187437513277e-05
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 2.1544346900318823e-05
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 2.8942661247167517e-05
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 3.888155180308085e-05
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 5.223345074266833e-05
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 7.017038286703822e-05
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 9.426684551178853e-05
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 0.00012663801734674022
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 0.00017012542798525856
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 0.00022854638641349884
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 0.00030702906297578496
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 0.00041246263829013477
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 0.000554102033000948
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 0.000744380301325168
# loss nan
# degree 8
#
#
#
# No. of clusters 105
# lambda 0.001
# loss nan
# degree 8
#
#
#
# 4 1e-08 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-21e45ec350f2> in <module>
#      19     ls_opt_d.append(opt_d)
#      20     ls_opt_l.append(opt_l)
# ---> 21     ls_opt_k.append(opt_k)
#
# NameError: name 'ls_opt_k' is not defined

# %% [markdown]
# ## Logistic Regression

# %%
print(ls_opt_d, ls_opt_l)
opt_d_0 = 8
opt_d_1 = 8
opt_d_23 = 8
# Out:
# [4] [1e-08]

# %%
opt_l_0 = 3.3932217718953295e-07
opt_l_1 = 5.1794746792312124e-08
opt_l_23 = 1e-08

# %%
accuracy = []
op_lambda = []

# %%
i = 23
tx, opt_d, y_jet, opt_l = tx_23, opt_d_23, y_jet_23, opt_l_23
poly_tx_te = build_poly(tx, opt_d)
quanzhong, _ = ridge_regression(y_jet, poly_tx_te, opt_l)
p = predict_labels(quanzhong, poly_tx_te)
print('Accuracy for jet = '+ str(i))
accuracy.append(np.sum(p==y_jet))
op_lambda.append(opt_l)
print(accuracy, len(y_jet))
print(np.sum(p==y_jet)/len(y_jet))
# Out:
# Accuracy for jet = 23
# [82954, 60476, 58330] 72543
# 0.8040748245867968

# %%
#k mean cluster 11
kmc1_acc = accuracy
kmc1_lambda = op_lambda
print(sum(kmc_acc)/250000)
print(kmc1_acc)
print(kmc1_lambda)
# Out:
# 0.805564
# [82954, 60476, 58330]
# [3.3932217718953295e-07, 5.1794746792312124e-08, 1e-08]

# %%
#linear Regression

#kmc_acc = accuracy
#kmc_lambda = op_lambda
print(sum(kmc_acc)/250000)
print(kmc_acc)
print(kmc_lambda)
# Out:
# 0.805564
# [82891, 60519, 57981]
# [1.67683293681101e-07, 1e-08, 1e-08]

# %%
# meaningless
#regression2_acc = accuracy 
#mei you normalize
#regression2_lambda = op_lambda
print(sum(regression2_acc)/250000)
print(regression2_acc)
print(regression2_lambda)
# Out:
# 0.795996
# [81711, 59334, 57954]
# [0.0007880462815669912, 2.811768697974231e-06, 1.030917620904739e-10]

# %%
mean_acc = accuracy
mean_lambda = op_lambda
print(sum(mean_acc)/250000)
print(mean_acc)
print(mean_lambda)

# %%
#median_acc = accuracy
#median_lambda = op_lambda
print(sum(median_acc)/250000)
print(median_acc)
print(median_lambda)
# Out:
# 0.802208
# [81614, 60623, 58315]
# [0.0014873521072935117, 0.0014873521072935117, 0.0028072162039411755]

# %%
#median2_acc = accuracy 80.2
#median2_lambda = op_lambda
print(sum(median2_acc)/250000)
print(median2_acc)
print(median2_lambda)
# Out:
# 0.801596
# [81614, 60558, 58227]
# [0.0014873521072935117, 0.01, 0.007278953843983146]

# %% [markdown]
# ## Generate predictions and save ouput in csv format for submission:

# %%
DATA_TEST_PATH = '../data/test.csv' # TODO: download train data and supply path here 
_, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
# OUTPUT_PATH = 'data/pred.csv' # TODO: fill in desired name of output file for submission
# y_pred = predict_labels(weights, tX_test)
# create_csv_submission(ids_test, y_pred, OUTPUT_PATH)

# %%
t0, t1, t23, t_ids = split_reformat_test(tX_test, ids_test)


print(t0.shape)
print(t1.shape)
print(t23.shape)
# Out:
# (227458, 18)
# (175338, 22)
# (165442, 29)

# %%
len(quanzhong)
# Out:
# 111

# %%
poly_t1 = build_poly(t1, opt_d)


p = predict_labels(quanzhong, poly_t1)

# %%
len(p[p == 1]) / len(p)
# Out:
# 0.1306904378970902

# %%
len(y_jet_1[y_jet_1 == 1]) / len(y_jet_1)
# Out:
# 0.35734550706695556
